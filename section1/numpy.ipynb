# %% [markdown]
# # np.array

# %%
  import numpy as np
  x = np.array([1,3,2,5])
  x
# Out:
# array([1, 3, 2, 5])

# %%
a = [1,2,3]
b = [4,5,6]
print(a + b)

x = np.array([1,3,2])
y = np.array([4,5,6])
print(x + y)

#違いに注目
# Out:
# [1, 2, 3, 4, 5, 6]
# [5 8 8]

# %%
a = [[1,2], [2,4]]
x = np.array([[1,2],[3,2]])
print(a)
print(x.shape)
print(x.ndim)
 #print(a.shape)だとエラーが出る　配列のクラスが指定されているのがメリット
# Out:
# [[1, 2], [2, 4]]
# (2, 2)
# 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-85c0977ffa09> in <cell line: 6>()
#       4 print(x.shape)
#       5 print(x.ndim)
# ----> 6 print(a.shape)
#       7
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
x = np.random()

# %% [markdown]
# #乱数

# %%
x = np.random.normal(0, 1, 50)
print(x)
from numpy.random import normal
x = normal(0, 1, 50)
print(x)
# Out:
# [ 1.57702046 -0.58680105  0.69390824  1.13679714 -2.17468855 -0.19042301
#   0.26313156  1.58180236 -1.3045673   0.82320211 -0.34627088  0.44064314
#   0.52769691 -0.76432178  0.39368223 -1.90963487 -1.8604691  -0.61059911
#  -1.56124396 -0.33958643  0.86177164 -0.28198176 -0.39104619  0.11169552
#   0.64676545  2.16177127 -0.08197967 -0.65470027 -0.03919755  2.31294763
#   0.2882911   0.93251559 -0.14448924  0.9288164  -1.46953135  0.39691771
#   0.22389105 -0.40977126 -0.93938786 -0.83649557  1.83733996 -1.11695377
#   0.81895717 -1.73830807  0.57920999 -1.83260283 -1.5151793  -0.6614409
#   1.63108881 -0.3713578 ]
# [ 1.24475184 -1.07039768 -0.14628911  2.1942283   1.19791559 -0.71200166
#  -0.85077924 -0.42161996 -0.36713356 -0.28268766 -1.64300889  1.34040948
#   1.46798873  1.84726205 -1.26200439 -0.61954013 -0.63813859  0.46105283
#  -0.25354335  0.12907518 -1.37074559 -1.20724641 -0.99271424  1.01552487
# ...

# %%
y = x + normal (50, 0.1, 50)
print(np.corrcoef(x, y))
# Out:
# [[1.         0.99413985]
#  [0.99413985 1.        ]]

# %%
from numpy.random import seed
seed(1303)
print(normal(0,1,3))
print(normal(0 ,1 ,3))
seed(1303)
print(normal(0,1,3))
# Out:
# [-0.03425693  0.06035959  0.45511859]
# [-0.36593175 -1.6773304   0.5910023 ]
# [-0.03425693  0.06035959  0.45511859]

# %%
seed(3)
y = normal(0 , 1, 100)
print(np.mean(y))
print(np.var(y))
print(np.sqrt(np.var(y)))
print(np.std(y))
# Out:
# -0.10863707440606224
# 1.132081888283007
# 1.0639933685333791
# 1.0639933685333791

# %% [markdown]
# #matplotlib

# %%
import matplotlib.pyplot as plt

# %%
from google.colab import files
seed(100)
x = normal(0,1,10)
y = normal(0,1,10)
plt.scatter(x, y)
plt.show()

# %%
from google.colab import files
seed(100)
plt.scatter(x,y)
plt.savefig("fig.png")

# %%
x = np.linspace(0, 2, 100)
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y = x
X ,Y = np.meshgrid(x, y)
f = np.cos(Y)/ (1 + np.square(X))
plt.contour(X, Y, f)
plt.show()

# %%
fa = (f -f.T)/2
plt.imshow(fa, extent= (x[0], x[-1], y[0], y[-1]))
plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(X, Y , fa)
plt.show()

# %% [markdown]
# # tensor

# %%
import numpy as np

# %%
m1 = np.array([[5,12,6], [-3, 0, 14]])
m1.shape
# Out:
# (2, 3)

# %%
m2 = np.array([[5,12,6], [-3,0, 14]])
m2.shape
# Out:
# (2, 3)

# %%
t = np.array([m1, m2])
t.shape
# Out:
# (2, 2, 3)

# %%
t_manual = np.array([[[1,2,3],[4,5,6]],[[9,8,7],[6,5,4]]])
t_manual.shape
# Out:
# (2, 2, 3)

# %%
m1 + 1 # it is possible to add matrix and schalor
# Out:
# array([[ 6, 13,  7],
#        [-2,  1, 15]])

# %%
x = np.array([1,2,3])
y = np.array([4,5,6])
np.dot(x,y)
# Out:
# 32
